# %%
# !pip install yellowbrick
#Import the necesary libraries
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans
from sklearn.cluster import DBSCAN
from sklearn.mixture import GaussianMixture
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score
import warnings
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import os
import dotenv
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.metrics import silhouette_score
warnings.filterwarnings("ignore")




data = pd.read_csv(r"C:\Users\basil\OneDrive\Escritorio\Ironhack\labs\lab-API-wrappers.csv")
data
# Out:
# Requirement already satisfied: yellowbrick in c:\users\basil\anaconda3\lib\site-packages (1.5)
# Requirement already satisfied: matplotlib!=3.0.0,>=2.0.2 in c:\users\basil\anaconda3\lib\site-packages (from yellowbrick) (3.7.2)
# Requirement already satisfied: scipy>=1.0.0 in c:\users\basil\anaconda3\lib\site-packages (from yellowbrick) (1.11.1)
# Requirement already satisfied: scikit-learn>=1.0.0 in c:\users\basil\anaconda3\lib\site-packages (from yellowbrick) (1.3.2)
# Requirement already satisfied: numpy>=1.16.0 in c:\users\basil\anaconda3\lib\site-packages (from yellowbrick) (1.24.3)
# Requirement already satisfied: cycler>=0.10.0 in c:\users\basil\anaconda3\lib\site-packages (from yellowbrick) (0.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\basil\anaconda3\lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (1.0.5)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\basil\anaconda3\lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\basil\anaconda3\lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\basil\anaconda3\lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\basil\anaconda3\lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (9.4.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\basil\anaconda3\lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\basil\anaconda3\lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (2.8.2)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\basil\anaconda3\lib\site-packages (from scikit-learn>=1.0.0->yellowbrick) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\basil\anaconda3\lib\site-packages (from scikit-learn>=1.0.0->yellowbrick) (2.2.0)
# Requirement already satisfied: six>=1.5 in c:\users\basil\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.0.0,>=2.0.2->yellowbrick) (1.16.0)
#                         Canción                 Artista  danceability  energy  \
# 0                     Três Dias          Marcelo Camelo         0.291   0.319
# 1                  Elephant Gun                  Beirut         0.171   0.626
# 2                   Fake Empire            The National         0.324   0.776
# 3               Sorriso ao Sono             Phill Veras         0.627   0.342
# 4                   I Will Wait          Mumford & Sons         0.486   0.769
# ..                          ...                     ...           ...     ...
# 212                   Daft Punk              Pentatonix         0.717   0.621
# 213                  YEAH RIGHT                    Joji         0.672   0.588
# 214  Allen Page's Midnight Ride         Panucci's Pizza         0.558   0.448
# 215            This Bitter Pill  Dashboard Confessional         0.544   0.380
# 216               Love Yourself  Dashboard Confessional         0.590   0.311
#
#      key  loudness  mode  speechiness  acousticness  instrumentalness  \
# 0      7   -10.465     1       0.0306       0.79100           0.46800
# 1      8    -8.677     1       0.0486       0.87300           0.02520
# 2      0    -6.784     1       0.0346       0.15100           0.91700
# 3      2   -12.833     1       0.0394       0.70000           0.16600
# 4      1    -5.140     1       0.0341       0.01190           0.00832
# ..   ...       ...   ...          ...           ...               ...
# 212   11    -7.588     0       0.0605       0.00403           0.00000
# 213    1    -9.573     1       0.1330       0.61900           0.24100
# 214    5    -6.522     1       0.0410       0.50600           0.00000
# 215    6    -9.219     1       0.0251       0.64300           0.00000
# 216    6   -10.394     1       0.0325       0.87500           0.03630
#
#      liveness  valence    tempo            type                      id  \
# 0      0.0692    0.038  103.793  audio_features  0A0eOcimSNRs2EQQlH7FFJ
# 1      0.0681    0.457  180.098  audio_features  0MtVmhAx6CxNuxFIUc6Mj9
# 2      0.0728    0.317  101.964  audio_features  6aUAF8JOd8zEl41B6I18xL
# 3      0.0820    0.513   80.030  audio_features  2vGvPQNnyybJmiqpr1HiKX
# 4      0.1970    0.393  131.286  audio_features  1PuLHwFZoh5qYK89I5YBdZ
# ..        ...      ...      ...             ...                     ...
# 212    0.1440    0.720  133.014  audio_features  6ukvsBzq4d1vBsAUmz7ZVt
# 213    0.0992    0.204  169.033  audio_features  1VGzxJnVQND7Cg5H5wGj14
# 214    0.0898    0.159  117.984  audio_features  2EYMmP358cUvHnTUHh8dJQ
# 215    0.1150    0.390   63.330  audio_features  3tEJXdNmXzu5Pcrgq9IKjv
# 216    0.0959    0.538   81.951  audio_features  3ZuocMfgdJiiqRZKerYXBN
#
#                                       uri  \
# 0    spotify:track:0A0eOcimSNRs2EQQlH7FFJ
# 1    spotify:track:0MtVmhAx6CxNuxFIUc6Mj9
# 2    spotify:track:6aUAF8JOd8zEl41B6I18xL
# 3    spotify:track:2vGvPQNnyybJmiqpr1HiKX
# 4    spotify:track:1PuLHwFZoh5qYK89I5YBdZ
# ..                                    ...
# 212  spotify:track:6ukvsBzq4d1vBsAUmz7ZVt
# 213  spotify:track:1VGzxJnVQND7Cg5H5wGj14
# 214  spotify:track:2EYMmP358cUvHnTUHh8dJQ
# 215  spotify:track:3tEJXdNmXzu5Pcrgq9IKjv
# 216  spotify:track:3ZuocMfgdJiiqRZKerYXBN
#
#                                             track_href  \
# 0    https://api.spotify.com/v1/tracks/0A0eOcimSNRs...
# 1    https://api.spotify.com/v1/tracks/0MtVmhAx6CxN...
# 2    https://api.spotify.com/v1/tracks/6aUAF8JOd8zE...
# 3    https://api.spotify.com/v1/tracks/2vGvPQNnyybJ...
# 4    https://api.spotify.com/v1/tracks/1PuLHwFZoh5q...
# ..                                                 ...
# 212  https://api.spotify.com/v1/tracks/6ukvsBzq4d1v...
# 213  https://api.spotify.com/v1/tracks/1VGzxJnVQND7...
# 214  https://api.spotify.com/v1/tracks/2EYMmP358cUv...
# 215  https://api.spotify.com/v1/tracks/3tEJXdNmXzu5...
# 216  https://api.spotify.com/v1/tracks/3ZuocMfgdJii...
#
#                                           analysis_url  duration_ms  \
# 0    https://api.spotify.com/v1/audio-analysis/0A0e...       323280
# 1    https://api.spotify.com/v1/audio-analysis/0MtV...       348893
# 2    https://api.spotify.com/v1/audio-analysis/6aUA...       205040
# 3    https://api.spotify.com/v1/audio-analysis/2vGv...       248480
# 4    https://api.spotify.com/v1/audio-analysis/1PuL...       276720
# ..                                                 ...          ...
# 212  https://api.spotify.com/v1/audio-analysis/6ukv...       248560
# 213  https://api.spotify.com/v1/audio-analysis/1VGz...       174358
# 214  https://api.spotify.com/v1/audio-analysis/2EYM...       114590
# 215  https://api.spotify.com/v1/audio-analysis/3tEJ...       193773
# 216  https://api.spotify.com/v1/audio-analysis/3Zuo...       312224
#
#      time_signature
# 0                 3
# 1                 3
# 2                 3
# 3                 4
# 4                 4
# ..              ...
# 212               4
# 213               4
# 214               3
# 215               4
# 216               4
#
# [217 rows x 20 columns]

# %%
# Selecciona solo las columnas numéricas para escalar
numeric_columns = data.select_dtypes(include=['int', 'float']).columns

# Escala los datos
scaler = StandardScaler()
X_prep = scaler.fit_transform(data[numeric_columns])

# %%
# Crea una instancia de KMeans
kmeans = KMeans(n_clusters=5, random_state=42)

# Ajusta el modelo KMeans a los datos escalados
kmeans.fit(X_prep)
# Out:
# KMeans(n_clusters=5, random_state=42)

# %%
# predecir |  asignar clusters:
clusters = kmeans.predict(X_prep)
clusters
# Out:
# array([3, 3, 3, 2, 1, 3, 1, 2, 4, 1, 0, 2, 1, 1, 4, 1, 2, 0, 3, 3, 2, 0,
#        1, 1, 2, 0, 3, 0, 2, 1, 1, 1, 1, 2, 1, 3, 1, 1, 3, 2, 4, 0, 3, 0,
#        2, 2, 2, 2, 2, 2, 3, 2, 2, 2, 1, 0, 2, 2, 3, 1, 2, 1, 3, 0, 1, 3,
#        2, 1, 2, 2, 2, 1, 1, 4, 1, 1, 4, 0, 2, 2, 2, 2, 2, 1, 1, 2, 2, 0,
#        1, 2, 2, 3, 1, 2, 2, 2, 1, 2, 2, 2, 3, 0, 1, 2, 1, 0, 2, 3, 2, 0,
#        1, 2, 2, 2, 2, 2, 2, 3, 3, 2, 1, 0, 2, 2, 0, 2, 2, 2, 1, 0, 2, 0,
#        2, 1, 1, 2, 1, 1, 2, 3, 1, 0, 0, 2, 3, 2, 2, 1, 1, 3, 2, 1, 2, 4,
#        1, 1, 0, 1, 2, 1, 1, 1, 2, 4, 1, 1, 1, 3, 1, 2, 1, 2, 1, 2, 1, 0,
#        1, 1, 1, 2, 2, 1, 0, 1, 4, 1, 0, 0, 2, 1, 1, 1, 4, 1, 1, 3, 0, 4,
#        4, 4, 0, 3, 3, 1, 1, 2, 4, 1, 1, 4, 4, 1, 0, 1, 3, 2, 2])

# %%
# ver el tamaño de los clusters
pd.Series(clusters).value_counts().sort_index()
# Out:
# 0    28
# 1    72
# 2    75
# 3    27
# 4    15
# Name: count, dtype: int64

# %%
# Explore the cluster assignment in the original dataset
X_df = data
X_df["cluster"] = clusters
X_df.head()

X_df['cluster'] = X_df['cluster'].apply(lambda x: 0 if x == 1 else 1 if x == 2 else 2)
X_df
# Out:
#                         Canción                 Artista  danceability  energy  \
# 0                     Três Dias          Marcelo Camelo         0.291   0.319
# 1                  Elephant Gun                  Beirut         0.171   0.626
# 2                   Fake Empire            The National         0.324   0.776
# 3               Sorriso ao Sono             Phill Veras         0.627   0.342
# 4                   I Will Wait          Mumford & Sons         0.486   0.769
# ..                          ...                     ...           ...     ...
# 212                   Daft Punk              Pentatonix         0.717   0.621
# 213                  YEAH RIGHT                    Joji         0.672   0.588
# 214  Allen Page's Midnight Ride         Panucci's Pizza         0.558   0.448
# 215            This Bitter Pill  Dashboard Confessional         0.544   0.380
# 216               Love Yourself  Dashboard Confessional         0.590   0.311
#
#      key  loudness  mode  speechiness  acousticness  instrumentalness  ...  \
# 0      7   -10.465     1       0.0306       0.79100           0.46800  ...
# 1      8    -8.677     1       0.0486       0.87300           0.02520  ...
# 2      0    -6.784     1       0.0346       0.15100           0.91700  ...
# 3      2   -12.833     1       0.0394       0.70000           0.16600  ...
# 4      1    -5.140     1       0.0341       0.01190           0.00832  ...
# ..   ...       ...   ...          ...           ...               ...  ...
# 212   11    -7.588     0       0.0605       0.00403           0.00000  ...
# 213    1    -9.573     1       0.1330       0.61900           0.24100  ...
# 214    5    -6.522     1       0.0410       0.50600           0.00000  ...
# 215    6    -9.219     1       0.0251       0.64300           0.00000  ...
# 216    6   -10.394     1       0.0325       0.87500           0.03630  ...
#
#      valence    tempo            type                      id  \
# 0      0.038  103.793  audio_features  0A0eOcimSNRs2EQQlH7FFJ
# 1      0.457  180.098  audio_features  0MtVmhAx6CxNuxFIUc6Mj9
# 2      0.317  101.964  audio_features  6aUAF8JOd8zEl41B6I18xL
# 3      0.513   80.030  audio_features  2vGvPQNnyybJmiqpr1HiKX
# 4      0.393  131.286  audio_features  1PuLHwFZoh5qYK89I5YBdZ
# ..       ...      ...             ...                     ...
# 212    0.720  133.014  audio_features  6ukvsBzq4d1vBsAUmz7ZVt
# 213    0.204  169.033  audio_features  1VGzxJnVQND7Cg5H5wGj14
# 214    0.159  117.984  audio_features  2EYMmP358cUvHnTUHh8dJQ
# 215    0.390   63.330  audio_features  3tEJXdNmXzu5Pcrgq9IKjv
# 216    0.538   81.951  audio_features  3ZuocMfgdJiiqRZKerYXBN
#
#                                       uri  \
# 0    spotify:track:0A0eOcimSNRs2EQQlH7FFJ
# 1    spotify:track:0MtVmhAx6CxNuxFIUc6Mj9
# 2    spotify:track:6aUAF8JOd8zEl41B6I18xL
# 3    spotify:track:2vGvPQNnyybJmiqpr1HiKX
# 4    spotify:track:1PuLHwFZoh5qYK89I5YBdZ
# ..                                    ...
# 212  spotify:track:6ukvsBzq4d1vBsAUmz7ZVt
# 213  spotify:track:1VGzxJnVQND7Cg5H5wGj14
# 214  spotify:track:2EYMmP358cUvHnTUHh8dJQ
# 215  spotify:track:3tEJXdNmXzu5Pcrgq9IKjv
# 216  spotify:track:3ZuocMfgdJiiqRZKerYXBN
#
#                                             track_href  \
# 0    https://api.spotify.com/v1/tracks/0A0eOcimSNRs...
# 1    https://api.spotify.com/v1/tracks/0MtVmhAx6CxN...
# 2    https://api.spotify.com/v1/tracks/6aUAF8JOd8zE...
# 3    https://api.spotify.com/v1/tracks/2vGvPQNnyybJ...
# 4    https://api.spotify.com/v1/tracks/1PuLHwFZoh5q...
# ..                                                 ...
# 212  https://api.spotify.com/v1/tracks/6ukvsBzq4d1v...
# 213  https://api.spotify.com/v1/tracks/1VGzxJnVQND7...
# 214  https://api.spotify.com/v1/tracks/2EYMmP358cUv...
# 215  https://api.spotify.com/v1/tracks/3tEJXdNmXzu5...
# 216  https://api.spotify.com/v1/tracks/3ZuocMfgdJii...
#
#                                           analysis_url duration_ms  \
# 0    https://api.spotify.com/v1/audio-analysis/0A0e...      323280
# 1    https://api.spotify.com/v1/audio-analysis/0MtV...      348893
# 2    https://api.spotify.com/v1/audio-analysis/6aUA...      205040
# 3    https://api.spotify.com/v1/audio-analysis/2vGv...      248480
# 4    https://api.spotify.com/v1/audio-analysis/1PuL...      276720
# ..                                                 ...         ...
# 212  https://api.spotify.com/v1/audio-analysis/6ukv...      248560
# 213  https://api.spotify.com/v1/audio-analysis/1VGz...      174358
# 214  https://api.spotify.com/v1/audio-analysis/2EYM...      114590
# 215  https://api.spotify.com/v1/audio-analysis/3tEJ...      193773
# 216  https://api.spotify.com/v1/audio-analysis/3Zuo...      312224
#
#      time_signature  cluster
# 0                 3        2
# 1                 3        2
# 2                 3        2
# 3                 4        1
# 4                 4        0
# ..              ...      ...
# 212               4        2
# 213               4        0
# 214               3        2
# 215               4        1
# 216               4        1
#
# [217 rows x 21 columns]

# %%
kmeans.inertia_
# Out:
# 1946.037549124234

# %%
import numpy as np

K = range(2, 20)

inertia = []

for k in K:
    kmeans = KMeans(n_clusters=k, random_state=1234)
    kmeans.fit(X_prep)
    inertia.append(kmeans.inertia_)

inertia
# Out:
# [2423.3004998020633,
#  2243.6154968391897,
#  2094.188342481386,
#  1975.773413915357,
#  1849.979111482665,
#  1769.7584500477192,
#  1687.8885125665588,
#  1548.3430070465542,
#  1549.6140610938169,
#  1503.711282385523,
#  1411.4795291676385,
#  1395.41198497687,
#  1349.6423620230307,
#  1310.2336520649424,
#  1283.7800353667112,
#  1261.451299493191,
#  1239.7325728904561,
#  1198.1112239024508]

# %%
# "performance metric"
kmeans.inertia_
# Out:
# 1198.1112239024508

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(16,8))
plt.plot(K, inertia, 'bx-')
plt.title('Inertia Methond')
plt.xlabel('k')
plt.ylabel('inertia')
plt.xticks(np.arange(min(K), max(K)+1, 1.0))
plt.show()

# %%
#Checking the optimal number of clusters
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, init='k-means++', max_iter=300, n_init=10, random_state=42)
    kmeans.fit(X_prep)
    wcss.append(kmeans.inertia_)

# %%
inertia = []
silhouette_scores = []
ranges = range(2,15)

for k in ranges:
    kmeans = KMeans(n_clusters=k, random_state=42, n_init=10).fit(X_prep)
    inertia.append(kmeans.inertia_)

    silhouette_avg = silhouette_score(X_prep, kmeans.labels_)
    silhouette_scores.append(silhouette_avg)

plt.plot(ranges,inertia, marker = "o")
plt.show()

plt.plot(ranges, silhouette_scores, marker="o")

# %%
plt.figure(figsize=(12,6))
plt.plot(range(1, 11), wcss, marker='o', linestyle='--')
plt.xlabel('Number of Clusters')
plt.ylabel('WCSS')
plt.title('Elbow Method - Optimal Number of Clusters')
plt.show()

# %%
from sklearn.cluster import KMeans
from yellowbrick.cluster import KElbowVisualizer

# Assuming you have already defined and scaled your 'cluster_data', if not, make sure you do that.

model = KMeans(n_clusters=3)  # You can change the number of clusters as needed
visualizer = KElbowVisualizer(model, k=(1,11))
visualizer.fit(X_prep)
visualizer.show()
# Out:
# <Axes: title={'center': 'Distortion Score Elbow for KMeans Clustering'}, xlabel='k', ylabel='distortion score'>

# %%
#Plotting the clusters and its centroids
pca = PCA(n_components=2)
pca_data = pca.fit_transform(X_prep)
pca_centers = pca.transform(kmeans.cluster_centers_)
plt.figure(figsize=(10, 10))
plt.scatter(pca_data[:, 0], pca_data[:, 1], c=kmeans.labels_, s=50, cmap='viridis')
plt.scatter(pca_centers[:, 0], pca_centers[:, 1], c='red', s=200, alpha=0.5)
plt.title('KMeans Clusters')
plt.show()

# %%
#Trying to cluster the data using DBSCAN
dbscan = DBSCAN(eps=0.5, min_samples=2)
dbscan.fit(X_prep)
data['cluster_dbscan'] = dbscan.labels_

data['cluster_dbscan'].value_counts()
# Out:
# cluster_dbscan
# -1    217
# Name: count, dtype: int64

# %%
#Trying to cluster the data using Gaussian Mixture
gmm = GaussianMixture(n_components=3)
gmm.fit(X_prep)
data['cluster_gmm'] = gmm.predict(X_prep)

data['cluster_gmm'].value_counts()
# Out:
# cluster_gmm
# 0    113
# 1     92
# 2     12
# Name: count, dtype: int64

# %%
#Plotting the clusters and its centroids
plt.figure(figsize=(10, 10))
plt.scatter(pca_data[:, 0], pca_data[:, 1], c=gmm.predict(X_prep), s=50, cmap='viridis')
plt.title('Gaussian Mixture Clusters')
plt.show()

# %%
#Creating a function to search for a song in the dataframe and return the cluster
def get_cluster(song):
    try:
        return data[data['Canción'] == song]['cluster'].values[0]
    except:
        return None

# %%
#Testing the function
get_cluster('Elephant Gun')
# Out:
# 2
